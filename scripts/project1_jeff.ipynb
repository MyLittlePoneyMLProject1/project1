# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Load the training data into feature matrix, class labels, and event ids:

# %%
from proj1_helpers import *

DATA_TRAIN_PATH = '../data/train.csv'
y, tX, ids = load_csv_data (DATA_TRAIN_PATH)

# %% [markdown]
# Data cleaning:

# %% [markdown]
# Divide the data into two classes, for y is 1 and -1

# %%
tX_yIS1 = np.array([row for i,row in enumerate(tX) if y[i] == 1.0])
tX_yISNOT1 = np.array([row for i,row in enumerate(tX) if y[i] == -1.0])
print(len(tX_yIS1), len(tX_yISNOT1))
# Out:
# 85667 164333

# %%
df_tX_yIS1 = pd.DataFrame (data = tX_yIS1)
df_tX_yIS1.columns = [('feature_' + str (i)) for i in range (30)] #['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt']

df_tX_yIS1.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  85667.000000  85667.000000  85667.000000  85667.000000  85667.000000
# mean      85.568853     32.036287     80.387179     74.869878   -619.259794
# std      202.476222     30.157585     21.457651     74.262307    486.123573
# min     -999.000000      0.000000      7.520000      0.000000   -999.000000
# 25%      105.592000     10.364000     67.382500     23.462500   -999.000000
# 50%      120.553000     24.403000     79.386000     54.376000   -999.000000
# 75%      134.739000     45.729000     91.936000    105.466500      1.965000
# max      977.333000    570.115000    789.538000   2834.999000      8.503000
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  85667.000000  85667.000000  85667.000000  85667.000000  85667.000000
# mean    -426.480218   -621.167191      2.386378     18.445728    182.989011
# ...

# %%
df_tX_yISNOT1 = pd.DataFrame (data = tX_yISNOT1)
df_tX_yISNOT1.columns = [('feature_' + str (i)) for i in range (30)] #['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt']

df_tX_yISNOT1.describe()
# Out:
#            feature_0      feature_1      feature_2      feature_3  \
# count  164333.000000  164333.000000  164333.000000  164333.000000
# mean     -119.186024      58.208042      81.596313      49.047438
# std       464.171448      34.520722      47.911004      55.326307
# min      -999.000000       0.000000       6.329000       0.000000
# 25%        53.224000      31.362000      55.532000       8.360000
# 50%        92.126000      60.812000      69.705000      32.880000
# 75%       122.460000      80.248000      92.716000      65.653000
# max      1192.026000     690.075000    1349.351000    1053.807000
#
#            feature_4      feature_5      feature_6      feature_7  \
# count  164333.000000  164333.000000  164333.000000  164333.000000
# mean     -754.900355    -692.338008    -755.329855       2.366178
# std       429.806453     552.692423     429.051909       0.827583
# min      -999.000000    -999.000000    -999.000000       0.208000
# ...

# %% [markdown]
# Compare y = 1 or -1 in different features

# %%
x_axis = range(30)

# red dashes, blue squares and green triangles
plt.plot(x_axis, tX_yIS1.mean(0), 'r', x_axis, tX_yISNOT1.mean(0), 'b')
plt.show()

# %%
x_axis = range(30)

y1 = tX_yIS1.mean(0)
e1 = tX_yIS1.std(0)
plt.errorbar(x_axis, y1, e1, marker='^', color='r')

y2 = tX_yISNOT1.mean(0)
e2 = tX_yISNOT1.std(0)
plt.errorbar(x_axis, y2, e2, marker='^', color='b')

plt.show()

# %% [markdown]
# Try out the purified tX!!!

# %%
from dataCleaning import *

# Transform tX into tX_pure
tX_pure = remove_features_999(tX)
print(tX_pure.shape)
# Out:
# (250000, 19)

# %%
tX_pure_yIS1 = np.array([row for i,row in enumerate(tX_pure) if y[i] == 1.0])
tX_pure_yISNOT1 = np.array([row for i,row in enumerate(tX_pure) if y[i] == -1.0])

feature_length = tX_pure.shape[1]

# %%
x_axis = range(feature_length)

# red dashes, blue squares and green triangles
plt.plot(x_axis, tX_pure_yIS1.mean(0), 'r', x_axis, tX_pure_yISNOT1.mean(0), 'b')
plt.show()

# %%
x_axis = range(feature_length)

y1 = tX_pure_yIS1.mean(0)
e1 = tX_pure_yIS1.std(0)
plt.errorbar(x_axis, y1, e1, marker='^', color='r')

y2 = tX_pure_yISNOT1.mean(0)
e2 = tX_pure_yISNOT1.std(0)
plt.errorbar(x_axis, y2, e2, marker='^', color='b')

plt.show()
